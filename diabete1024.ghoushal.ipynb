# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghoushal/ghoushal/blob/main/diabete1024.ghoushal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
url="https://raw.githubusercontent.com/Ghoushal/ghoushal/main/diabetes2.csv"
df2=pd.read_csv(url,header=None)

# %%
df2.head(7)
# Out:
#              0        1              2              3        4     5  \
# 0  pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
# 5            0      137             40             35      168  43.1
# 6            5      116             74              0        0  25.6
#
#           6    7        8
# 0  diabetes  age  outcome
# 1     0.627   50        1
# 2     0.351   31        0
# 3     0.672   32        1
# 4     0.167   21        0
# 5     2.288   33        1
# 6     0.201   30        0
